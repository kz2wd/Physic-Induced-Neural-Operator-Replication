# %%
from torch import Tensor, nn
import torch
import numpy as np

import os
import zarr
import s3fs
from torch.utils.data import Dataset
import torch
import torch.nn.functional as F

from dataset_loader import LDCDataset

# %%
from sklearn.decomposition import PCA

dataset = LDCDataset("ds3", 65, 100)
data_x = dataset.X

# %%
data_x = data_x[..., :3]

# %%
torch.mean(data_x)
# Out:
# tensor(0.0002, dtype=torch.float64)

# %%
torch.var(data_x)
# Out:
# tensor(0.1600, dtype=torch.float64)

# %%
data_x.shape
# Out:
# torch.Size([100, 65, 65, 3])

# %%
np.isnan(data_x).sum()
# Out:
# /tmp/ipykernel_7929/1439845615.py:1: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   np.isnan(data_x).sum()
# tensor(0)

# %%
dataset.Y.shape
# Out:
# torch.Size([100, 100, 65, 65, 3])

# %%
B, X, _, C = data_x.shape
X_pca = data_x.reshape(B, X*X*C)

# %%
# X_pca = data_x.reshape(B, C*X*X)

# %%
pca = PCA()
Z = pca.fit_transform(X_pca)

# %%
Z
# Out:
# array([[-8.01765517e+00, -3.33172872e+00,  1.29241126e+01, ...,
#         -1.51028018e-03, -3.95666195e-01,  6.08067030e-15],
#        [-7.03584072e+00, -3.22079603e+00, -9.29909052e-01, ...,
#         -4.49328954e-01, -1.65600139e+00,  6.08067030e-15],
#        [-1.76245061e+01,  4.26463199e+00, -1.63849155e+00, ...,
#         -2.57152137e-01, -3.40548468e-01,  6.08067030e-15],
#        ...,
#        [ 1.47423713e+01, -4.73249866e+00, -1.31791232e+00, ...,
#          1.81661132e-01, -2.93054230e-01,  6.08067030e-15],
#        [-1.41091382e-01,  1.72792955e+01, -4.71911387e+00, ...,
#          3.16264796e-01,  1.47942849e+00,  6.08067030e-15],
#        [-1.88758631e+01, -1.35936526e+01,  6.65259684e+00, ...,
#         -2.50239966e+00, -9.08790415e-01,  6.08067030e-15]],
#       shape=(100, 100))

# %%
import matplotlib.pyplot as plt
plt.scatter(Z[:,0], Z[:,1], c=range(len(Z)))
plt.colorbar()
plt.show()

# %%
pca.explained_variance_ratio_
# Out:
# array([5.05892557e-02, 4.39364612e-02, 4.12234879e-02, 3.98217235e-02,
#        3.68741532e-02, 3.47229716e-02, 3.16648771e-02, 2.91291015e-02,
#        2.74757936e-02, 2.63414164e-02, 2.55455877e-02, 2.41080005e-02,
#        2.40392486e-02, 2.27230556e-02, 2.17410808e-02, 2.06140632e-02,
#        1.96987098e-02, 1.88283157e-02, 1.78731852e-02, 1.75242250e-02,
#        1.63842015e-02, 1.54466558e-02, 1.51119184e-02, 1.50243882e-02,
#        1.36621407e-02, 1.34579658e-02, 1.28660145e-02, 1.26233449e-02,
#        1.20300921e-02, 1.13082562e-02, 1.11085258e-02, 1.10854339e-02,
#        9.85648766e-03, 9.50216527e-03, 9.32689127e-03, 9.02802301e-03,
#        8.48564481e-03, 8.42793292e-03, 8.34671057e-03, 7.79282065e-03,
#        7.33108354e-03, 7.04020537e-03, 6.94778547e-03, 6.87951557e-03,
#        6.65945923e-03, 6.32501474e-03, 6.05683260e-03, 5.94730451e-03,
#        5.62049728e-03, 5.55777680e-03, 5.30895041e-03, 4.88304403e-03,
#        4.82497830e-03, 4.71798257e-03, 4.57556772e-03, 4.40646835e-03,
#        4.22932890e-03, 4.13741112e-03, 3.88503613e-03, 3.81899681e-03,
#        3.69304957e-03, 3.58857350e-03, 3.50278603e-03, 3.41279392e-03,
#        3.34485588e-03, 3.25318066e-03, 3.01700453e-03, 2.97524377e-03,
#        2.92029403e-03, 2.85640070e-03, 2.71041869e-03, 2.58686238e-03,
#        2.53108916e-03, 2.51000147e-03, 2.43213146e-03, 2.30367492e-03,
#        2.28907177e-03, 2.16559779e-03, 2.14778511e-03, 2.14331049e-03,
#        2.02371785e-03, 1.94204587e-03, 1.90307189e-03, 1.81121132e-03,
#        1.78902124e-03, 1.71640287e-03, 1.67587075e-03, 1.62142130e-03,
#        1.57728370e-03, 1.52121416e-03, 1.47880179e-03, 1.39292053e-03,
#        1.36823209e-03, 1.33763965e-03, 1.29375273e-03, 1.24242018e-03,
#        1.18856313e-03, 1.13491323e-03, 1.09380247e-03, 1.90305311e-32])

# %%
plt.plot(pca.explained_variance_ratio_, marker='o')
plt.xlabel("component")
plt.ylabel("Explained variance ratio")
plt.show()

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o')
plt.xlabel("Number of components")
plt.ylabel("Cumulative explained variance")
plt.ylim(0,1)
plt.show()

# %%
data_y = dataset.Y

# %%
data_y = data_y[:, :]

# %%
data_y.shape
# Out:
# torch.Size([100, 100, 65, 65, 3])

# %%
torch.var(data_y, axis=(0, 2, 3, 4))
# Out:
# tensor([0.1600, 0.0663, 0.0493, 0.0255, 0.0313, 0.0198, 0.0240, 0.0204, 0.0219,
#         0.0192, 0.0144, 0.0177, 0.0125, 0.0180, 0.0135, 0.0173, 0.0148, 0.0162,
#         0.0161, 0.0145, 0.0164, 0.0140, 0.0170, 0.0143, 0.0166, 0.0152, 0.0162,
#         0.0160, 0.0156, 0.0167, 0.0154, 0.0171, 0.0157, 0.0172, 0.0162, 0.0170,
#         0.0169, 0.0169, 0.0174, 0.0169, 0.0179, 0.0171, 0.0180, 0.0175, 0.0181,
#         0.0179, 0.0181, 0.0184, 0.0182, 0.0187, 0.0184, 0.0190, 0.0187, 0.0191,
#         0.0192, 0.0193, 0.0195, 0.0195, 0.0198, 0.0197, 0.0201, 0.0200, 0.0203,
#         0.0203, 0.0204, 0.0206, 0.0206, 0.0209, 0.0209, 0.0211, 0.0211, 0.0213,
#         0.0214, 0.0216, 0.0217, 0.0217, 0.0219, 0.0220, 0.0221, 0.0222, 0.0224,
#         0.0224, 0.0226, 0.0227, 0.0228, 0.0229, 0.0230, 0.0231, 0.0232, 0.0233,
#         0.0234, 0.0235, 0.0236, 0.0237, 0.0238, 0.0239, 0.0240, 0.0240, 0.0241,
#         0.0242], dtype=torch.float64)

# %%
torch.norm(data_y)
# Out:
# tensor(1662.0060, dtype=torch.float64)

# %%
L2 = torch.nn.MSELoss(reduction="mean")
L2(data_y[:, 0], data_x)
# Out:
# tensor(1.7645e-33, dtype=torch.float64)

# %%
torch.var(data_x)
# Out:
# tensor(0.1600, dtype=torch.float64)

# %%
torch.norm(data_x)
# Out:
# tensor(450.3953, dtype=torch.float64)

# %%
B, T, X, _, C = data_y.shape
Y_pca = data_y.reshape(B*T, X*X*C)

# %%
pca = PCA()
Z = pca.fit_transform(Y_pca)

# %%
plt.scatter(Z[:,0], Z[:,1], c=range(len(Z)))
plt.colorbar()
plt.show()

plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o')
plt.xlabel("component")
plt.ylabel("Explained variance ratio")
plt.show()

# %%
B, T, X, _, C = data_y.shape
Y_pca = data_y.reshape(B, T*X*X*C)

# %%
pca = PCA()
Z = pca.fit_transform(Y_pca)

# %%
plt.scatter(Z[:,0], Z[:,1], c=range(len(Z)))
plt.colorbar()
plt.show()

plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o')
plt.xlabel("component")
plt.ylabel("Explained variance ratio")
plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# compress output
pca_y = PCA(n_components=50)
Y_red = pca_y.fit_transform(Y_pca)

# linear probe
model = LinearRegression().fit(X_pca, Y_red)
Y_pred = model.predict(X_pca)

print("R2:", r2_score(Y_red, Y_pred))
# Out:
# R2: 1.0

# %% [markdown]
# ## Check pde loss on simulation

# %%
L2 = torch.nn.MSELoss(reduction="mean")
NU_LAYER = 3
T = (0, 10)
dimT = 100
alpha = 1
beta = 1
dim = 65
# re & nu not fixed

k = 1
dt = (T[1] - T[0]) / dimT
dx = 1.0 / dim
# residual loss over time
def residual_loss(a, u):
    # assumed density to be 1
    # v viscosity (nu)
    # du/dt = -(u.∇)u + v∇.∇u -∇p
    # R = du/dt + (u.∇)u + ∇p - v∇.∇u

    
    TRS = np.s_[:, 2:]  # Time restriction
    
    INT = np.s_[:, :, 1:-1, 1:-1, :]  # Interior
    XPO = np.s_[:, :,   2:, 1:-1, :]  # X Plus One
    XMO = np.s_[:, :,  :-2, 1:-1, :]  # X Minus One
    YPO = np.s_[:, :, 1:-1,   2:, :]  # Y Plus One
    YMO = np.s_[:, :, 1:-1,  :-2, :]  # Y Minus One 

    u_vel = u[..., :2]
    u_vel_t = u_vel[TRS]
    p_t = u[TRS][..., 2:2 + 1]
    
    nu = a[None][INT][..., NU_LAYER:NU_LAYER + 1]
    
    du_dt = (u_vel[INT][:, 2:] - u_vel[INT][:, 1:-1]) / dt
    
    du_dx = (u_vel_t[XPO] - u_vel_t[XMO]) / dx
    du_dy = (u_vel_t[YPO] - u_vel_t[YMO]) / dx
    du_dx2 = (u_vel_t[XPO] + u_vel_t[XMO] - 2 * u_vel_t[INT]) / (dx * dx)
    du_dy2 = (u_vel_t[YPO] + u_vel_t[YMO] - 2 * u_vel_t[INT]) / (dx * dx)
    dp_dx = (p_t[XPO] - p_t[XMO]) / dx
    dp_dy = (p_t[YPO] - p_t[YMO]) / dx
    
    c0 = u_vel_t[INT][..., 0] * du_dx[..., 0] + u_vel_t[INT][..., 1] * du_dy[..., 0]
    c1 = u_vel_t[INT][..., 0] * du_dx[..., 1] + u_vel_t[INT][..., 1] * du_dy[..., 1]
    convection = torch.stack([c0, c1], dim=-1)
    
    viscosity = nu * (du_dx2 + du_dy2)

    grad_p = torch.cat([dp_dx, dp_dy], dim=-1)
    
    R = du_dt + convection + grad_p - viscosity

    return torch.mean(R**2)

def batched_bcu(u):
    K = 1
    # top - slip
    u[..., 1:-1, 0, 0] = 2 * K - u[..., 1:-1, 1, 0]
    u[..., 1:-1, 0, 1] = - u[..., 1:-1, 1, 1]
    # bot - no slip
    u[..., 1:-1, -1, :] = - u[..., 1:-1, -2, :]
    # left - no slip
    u[..., 0, 1:-1, :] = - u[..., 1, 1:-1, :]
    # right - no slip
    u[..., -1, 1:-1, :] = - u[..., -2, 1:-1, :]


# boundary condition loss over time
def bc_loss(u):
    # compute BC
    
    u_vel = u[..., :2]
    bcu = u_vel.clone().detach()
    batched_bcu(bcu)
    return (
        L2(u_vel[:, :, 1:-1,    0, :], bcu[:, :, 1:-1,    0, :]) +
        L2(u_vel[:, :, 1:-1,   -1, :], bcu[:, :, 1:-1,   -1, :]) +
        L2(u_vel[:, :,    0, 1:-1, :], bcu[:, :,    0, 1:-1, :]) +
        L2(u_vel[:, :,   -1, 1:-1, :], bcu[:, :,   -1, 1:-1, :])
    )

# initial condition loss
def ic_loss(a, u):
    ic_vel = a[:, :, :, :2]
    u0_vel = u[:, 0, :, :, :2]
    return L2(ic_vel, u0_vel)

# L pde is J pde as long as loss is averaged over batch
def L_pde(a, pred):
    return residual_loss(a, pred) + alpha * bc_loss(pred) + beta * ic_loss(a, pred)

# %%
from torch.utils.data import DataLoader
dataset = LDCDataset(dim, dimT)
x, y = next(iter(DataLoader(dataset, batch_size=1, shuffle=False)))

# %%
y.shape

# %%
L_pde(x, y)

# %%
L_pde(x, torch.rand(*y.shape))

# %%
 residual_loss(x, y)

# %%
bc_loss(y)

# %%
ic_loss(x, y)

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(data_y[0].cpu(), name="y")
napari.run()
