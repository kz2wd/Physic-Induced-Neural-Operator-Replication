# %%
from typing import override
from torch import Tensor, nn
import torch
import numpy as np


# Network hyperparam
dim = 65
dimT = 50
L = 4
mode = 8
width = 32
lr = 5e-4
du = 2  # 2 for x, y components.
da = du + 2  # 2 for viscosity and pressure

# PDE param
T = (5, 10)
re = 500
alpha = 1
beta = 1
k = 1

# NN


# Fourier Convolution Operator
class FCO(nn.Module):
    def __init__(self, mode: int) -> None:
        super().__init__()
        self.mode: int = mode
        self.R: nn.Module = nn.Linear(self.mode, self.mode, dtype=torch.complex64)  # Make complex

    @override
    def forward(self, x: Tensor) -> Tensor:
        # x of shape: (B, dim, dim, width)
        shape = x.shape
        fft = torch.fft.fftn(x, s=(self.mode, self.mode), dim=(1, 2))
        x = self.R(fft)
        print(x.shape)
        x = torch.fft.ifftn(x, s=shape, dim=())
        
        print(shape)
        return x


class PINOLayer(nn.Module):
    def __init__(self, mode: int, width: int) -> None:
        super().__init__()

        self.k: nn.Module = FCO(mode)
        self.w: nn.Module = nn.Linear(width, width)
        self.sigma: nn.Module = nn.GELU()

    @override
    def forward(self, x: Tensor) -> Tensor:
        w = self.w(x)
        k = self.k(x)
        x = self.sigma(w + k)
        return x


class PINO(nn.Module):
    def __init__(self, da: int, du: int, mode: int, width: int, L: int) -> None:
        super().__init__()

        # uplift
        R = nn.Linear(da, width)
        # projection
        Q = nn.Linear(width, du)

        layers = [PINOLayer(mode, width) for _ in range(L)]
        self.core: nn.Module = nn.Sequential(
            R,
            *layers,
            Q,
        )

    @override
    def forward(self, x: Tensor) -> Tensor:
        return self.core(x)

# %%
pino = PINO(da, du, mode, width, L)

# %%
Batch = 2
test_input = torch.rand(Batch, dim, dim, da)

# %%
output = pino(test_input)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 output = pino(test_input)
#
# File ~/vault/all-cfd/PINO/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/vault/all-cfd/PINO/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# Cell In[23], line 81, in PINO.forward(self, x)
#      79 @override
#      80 def forward(self, x: Tensor) -> Tensor:
# ---> 81     return self.core(x)
#
# File ~/vault/all-cfd/PINO/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/vault/all-cfd/PINO/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/vault/all-cfd/PINO/.venv/lib/python3.13/site-packages/torch/nn/modules/container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File ~/vault/all-cfd/PINO/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/vault/all-cfd/PINO/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# Cell In[23], line 58, in PINOLayer.forward(self, x)
#      55 @override
#      56 def forward(self, x: Tensor) -> Tensor:
#      57     w = self.w(x)
# ---> 58     k = self.k(x)
#      59     x = self.sigma(w + k)
#      60     return x
#
# File ~/vault/all-cfd/PINO/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/vault/all-cfd/PINO/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# Cell In[23], line 39, in FCO.forward(self, x)
#      37 shape = x.shape
#      38 fft = torch.fft.fftn(x, s=(self.mode, self.mode), dim=(1, 2))
# ---> 39 x = self.R(fft)
#      40 print(x.shape)
#      41 x = torch.fft.ifftn(x, s=shape, dim=())
#
# File ~/vault/all-cfd/PINO/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/vault/all-cfd/PINO/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/vault/all-cfd/PINO/.venv/lib/python3.13/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (128x32 and 8x8)

# %%
loss = output.sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 loss = output.sum()
#
# NameError: name 'output' is not defined

# %%
loss.backward()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 loss.backward()
#
# NameError: name 'loss' is not defined
